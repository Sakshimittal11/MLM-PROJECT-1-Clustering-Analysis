# %% [markdown]
# # **Segmentation of Software Developer Profiles using K-Means Clustering**
#
#
# **1. Project Objectives | Problem Statements**
#
# 1.1. PO1 | PS1: Segmentation of Software Developer Profiles using Unsupervised Machine Learning Clustering Algorithms
#
# 1.2. PO2 | PS2: Identification of Appropriate Number of Segments or Clusters
#
# 1.3. PO3 | PS3: Determination of Segment or Cluster Characteristics
#
#
# **2. Description of Data**
#
# **2.1. Data Source, Size, Shape**
#
# 2.1.1. Data Source (https://www.kaggle.com/datasets/stackoverflow/stack-overflow-2018-developer-survey)
#
# 2.1.2. Data Size (21MB)
#
# 2.1.3. Data Shape (Dimension: Number of Variables-129 | Number of Records-98,856 rows × 129 columns)
#
#
# **2.2. Description of Variables**
#
# *82.2.1. Index Variable(s)**
#
# Index Variable(s): Respondents
#
# **2.2. Variables or Features having Categories | Categorical Variables or Features (CV)**
#
# **2.2.2.1. Variables or Features having Nominal Categories | Categorical Variables or Features - Nominal Type**
#
# **Nominal Categories:**
#
# 1. RespondentHobby
# 2. Country
# 3. StudentEmployment
# 4. FormalEducation
# 5. UndergradMajor
# 6. CompanySize
# 7. DevType
# 8. Exercise
# 9. Gender
# 10. SexualOrientation
# 11. EducationParents
# 12. RaceEthnicity
# 13. Age
# 14. Dependents
# 15. Military
# 16. USSurveyTooLong
# 17. SurveyEasy
#
#
# **2.2.2.2. Variables or Features having Ordinal Categories | Categorical Variables or Features - Ordinal Type**
#
# **Ordinal Categories:**
#
# 1. Employment (Employed part-time, Employed full-time)
# 2. Dependents (Yes, No)
#
# **2.2.3. Non-Categorical Variables or Features Non-Categorical Variables or Features:**
#
# 1. Age
#
#
# **2.3. Descriptive Statistics**
#
# **2.3.1. Descriptive Statistics: Categorical Variables or Features**
#
# **2.3.1.1. Count | Frequency Statistics**
#
# The frequency statistics derived from the dataset reveal valuable insights into various aspects of job assessment, email priorities, salary, and advertisement preferences among respondents. The assessments for job satisfaction, represented by AssessJob1 to AssessJob9, were conducted for a total of 3268 respondents, indicating a comprehensive evaluation across multiple job-related factors. Similarly, job email priorities, as reflected in JobEmailPriorities1 to JobEmailPriorities7, were provided by 2161 to 2972 respondents, offering a glimpse into the importance placed on different aspects of email communication in the workplace. The dataset also includes information on the converted annual salaries of 2560 respondents, shedding light on the income distribution within the surveyed population. Furthermore, advertisement priorities, represented by AdsPriorities1 to AdsPriorities7, were reported by 2972 respondents, showcasing the varying preferences and interests regarding advertisement content. Overall, these frequency statistics provide a robust foundation for understanding the preferences, priorities, and demographics of the surveyed individuals across different domains.
#
# **2.3.1.2. Proportion (Relative Frequency) Statistics**
#
# The relative frequency statistics derived from the dataset provide a detailed view of participation levels and distributions across various dimensions. For job assessment variables like AssessJob1 to AssessJob9, all 3268 respondents contributed, showcasing a comprehensive assessment across different job-related factors. Job email priorities, ranging from JobEmailPriorities1 to JobEmailPriorities7, were reported by approximately 72% to 91% of respondents, highlighting the varying emphasis placed on different email communication aspects within the workplace. The dataset also includes converted annual salary data for 2560 respondents, giving insight into the income distribution among the surveyed population. Furthermore, advertisement priorities, represented by AdsPriorities1 to AdsPriorities7, were reported by approximately 72% to 100% of respondents, indicating a thorough understanding of preferences regarding advertisement content. These relative frequency statistics offer a nuanced perspective on the levels of participation and distributions within each variable, contributing to a deeper understanding of the preferences, assessments, and demographics of the surveyed individuals across different domains.
#
# **2.3.2. Descriptive Statistics: Non-Categorical Variables or Features**
#
# **2.3.2.1. Measures of Central Tendency**
#
#
# The measures of central tendency in the provided dataset offer insights into the average or typical values across various variables. For instance, the mean number of respondents across all columns is approximately 3226, suggesting the average participation level in the survey. In terms of job assessment scores (AssessJob1 to AssessJob9), the mean scores range from about 3.78 to 7.67, indicating the average ratings given by respondents across different job-related aspects. The mean converted salary is around 96718, providing an estimate of the average annual salary among the surveyed individuals. Similarly, for advertisement priorities (AdsPriorities1 to AdsPriorities7), the mean scores range from about 2.66 to 5.14, showcasing the average importance assigned to various advertisement factors. These measures of central tendency, including means and medians, offer a comprehensive view of the typical values and trends within the dataset across different variables and assessments.
#
# **2.3.2.2. Measures of Dispersion**
#
# The measures of dispersion in the provided dataset offer insights into the spread or variability of data points across different variables. The range of respondents' scores in job assessments (AssessJob1 to AssessJob9) varies from 1 to 10, indicating the diversity in opinions and ratings across different job-related aspects. Similarly, the range of converted salaries spans from 0 to approximately 2 million, showcasing the wide range of income levels among the respondents. The standard deviation and variance values for job assessments and advertisement priorities (AdsPriorities1 to AdsPriorities7) range from around 1.66 to 2.76, indicating the dispersion of scores and preferences around the mean values. The interquartile range (IQR) for these variables is relatively moderate, suggesting that a significant portion of respondents falls within a certain range of scores or priorities. Overall, these measures of dispersion highlight the variability and distribution of data points within each variable, providing a comprehensive view of the spread of responses and preferences among the surveyed individuals.
#
# **3. Analysis of Data**
#
# **3.1. Data Pre-Processing**
#
# **3.1.1. Missing Data Statistics and Treatment**
#
# **3.1.1.1.1. Missing Data Statistics: Records**
#
# It indicates that the "MilitaryUS" variable has the highest number of missing values, with 12704 entries missing, followed by "Dependents" with 4912 missing entries. This suggests a significant lack of data in these two variables. Additionally, "Age" has 4630 missing values, indicating a substantial amount of missing information regarding respondents' ages. The "SurveyTooLong" and "SurveyEasy" variables also show a considerable number of missing entries, with 4449 and 4456 missing values, respectively. On the other hand, variables like "Hobby," "OpenSource," and "Country" have no missing data, indicating that these aspects were fully covered in the survey responses.
#
# **3.1.1.1.2. Missing Data Treatment: Records**
#
# **3.1.1.1.2.1. Removal of Records with More Than 50% Missing Data**
#
# For the purpose of removing columns, a 50% missing values threshold—that is, more than half of the rows in a column with missing data—was set. No columns in the dataset exceeded this threshold, according to analysis. As a result, no
# columns were eliminated because of missing data.
#
# **3.1.1.2.1. Missing Data Statistics: Categorical Variables or Features Minimal Values Missing**
#
# The missing data in categorical variables within the provided dataset vary in terms of the number of missing entries and their proportion relative to the total data. For instance, the "Dependents" variable has 4912 missing entries, accounting for approximately 13.15% of the total data in that column. This indicates a significant absence of information regarding respondents' dependents. Similarly, the "MilitaryUS" variable has 12704 missing entries, representing around 33.93% of the total data, which is a substantial amount of missing information. On the other hand, the "Student" variable has 179 missing entries, making up about 0.48% of the total data, suggesting a relatively minor issue with missing data in this category.
#
# **3.1.1.2.2.1. Removal of Variables or Features with More Than 50% Missing Data**
#
# Again we have already checked for this aspect. There is no record where more than 50% data is missing and thus no data is treated
#
#
#
#
# **3.1.1.2.2.2. Imputation of Missing Data using Descriptive Statistics: Mode**
#
# The code for Simple imputer has been run in order to fill the missing values.
#
#
# **3.1.1.3.1. Missing Data Statistics: Non-Categorical Variables or Features**
#
# The "Age" variable in the dataset has 4630 missing entries, which accounts for approximately 12.36% of the total data in that column.
#
# **3.1.1.3.2. Missing Data Treatment: Non-Categorical Variables or Features**
#
# **3.1.1.3.2.1. Removal of Variables or Features with More Than 50% Missing Data**
#
# Again we have already checked for this aspect. There is no record where more than 50% data is missing and thus no data is treated
#
# **3.1.1.3.2.2. Imputation of Missing Data using Descriptive Statistics: Mean**
#
# There was no missing data but still code for imputing was ran & outcome was no change in dataset.
#
# **3.1.3. Outlier Statistics and Treatment (Scaling | Transformation)**
#
# **3.1.3.1.1. Outlier Statistics: Non-Categorical Variables or Features**
#
# The code used the Interquartile Range (IQR) approach to find outliers in the numerical columns. Outliers were defined as values that are significantly outside of 1.5 times the IQR, either above or below the third quartile. The code provided a thorough overview of the data distribution and identified potential anomalies by computing statistics like mean, standard deviation, quartiles, and the number of outliers. No outliers were found in speed Limit amongst non categorical variables.
#
# **3.1.3.1.2. Outlier Treatment: Non-Categorical Variables or Features**
#
# **3.1.3.1.2.1. Normalization using Min-Max Scaler**
#
# The outliers were treated in the following columns : 'Age'.
#
# **3.2. Data Analysis**
# In this section, we conduct a comprehensive analysis of the data using the K-Means clustering algorithm and evaluate its performance using various metrics.
#
# **3.2.1. Unsupervised Machine Learning Clustering Algorithm: K-Means (Base Model) | Metrics Used - Euclidean Distance**
# K-Means is employed to partition data points into K clusters based on the Euclidean distance metric. The choice of K significantly influences the granularity of the clustering and the interpretability of the results.
#
# **3.2.2. Clustering Model Performance Evaluation**
#
# **3.2.2.1. K Means Clustering Using the Elbow Method**
# In the Elbow method, we vary the number of clusters (K) from 1 to 10 and calculate WCSS (Within-Cluster Sum of Square) for each value of K. WCSS is the sum of the squared distance between each point and the centroid in a cluster. When plotted against the number of clusters, the plot exhibits an "Elbow" shape. The optimal value of K is identified at the point where the plot shows a significant change in slope before becoming almost parallel to the X-axis.
#
# **3.2.2.2. Silhouette Score | Davies-Bouldin Score (Base Model: K-Means)**
# Silhouette Score: Measures the cohesion and separation of clusters, with values ranging from -1 to 1. Higher scores indicate better-defined clusters.
# Davies-Bouldin Index: Measures the average similarity between each cluster and its most similar cluster. Lower values suggest better clustering.
# The evaluation is performed for different cluster sizes to identify the optimal number of clusters that maximize the Silhouette Score and minimize the Davies-Bouldin Index.
#
# **3.2.2.3. Clustering Model Performance Evaluation: Time Statistics | (CPU | GPU) Memory Statistics (Base Model: K-Means)**
# Time Statistics: Includes the time taken by the K-Means algorithm to converge for a given number of clusters.
# Memory Statistics: Refers to the memory consumption (CPU or GPU) by the K-Means algorithm during execution.
# These statistics offer insights into the computational efficiency and scalability of K-Means for different cluster sizes.
#
# **Detailed Analysis**
# K Means Clustering Using the Elbow Method:
# The Elbow method is employed to determine the optimal number of clusters (K) by analyzing the plot of WCSS against the number of clusters.
# The "Elbow" point on the plot indicates a significant change in slope, suggesting the optimal value of K.
#
# Silhouette Score and Davies-Bouldin Index Analysis:
# - **For 2 clusters**:
#   - sscore for k=2 :  0.5102132873488281
#   - dbscore for k=2 :  0.7103379531157534
#
# - **For 3 clusters**:
#   - sscore for k=3 :  0.4052008156897612
#   - dbscore for k=3 :  0.8720097149602711
#
# - **For 4 clusters** (Chosen Optimal):
#   - sscore for k=4 :  0.3772184645688922
#   - dbscore for k=4 :  0.948574475196601
#
# - **For 5 clusters**:
#   - sscore for k=5 :  0.3754650954781772
#   - dbscore for k=5 :  0.9612092356224003
#
# These metrics aid in determining the optimal number of clusters, balancing cohesion and separation.
#
# Time and Memory Statistics Analysis:
# - **For k=3** (Chosen Optimal):
#   - Time taken by K-Means for k=3: 0.6595537662506104 seconds
#   - Memory used by K-Means for k=3: O bytes
#
# This analysis showcases the computational efficiency and resource requirements of K-Means, guiding the selection of an appropriate cluster size.
# Conclusion
# The evaluation of the K-Means clustering model provides valuable insights into the clustering quality and computational efficiency. Based on the metrics analyzed, K=3 is chosen as the optimal number of clusters, ensuring meaningful groupings of data points while maintaining computational scalability. Theoretical insights into the metrics used enhance the understanding of the clustering process and its outcomes, facilitating informed decision-making. Additionally, the Elbow method aids in confirming the optimal value of K, providing a comprehensive approach to cluster analysis.
#
# **3.2.2.1. Cluster Analysis: Base Model (K-Means)**
#
# **3.2.3.1.1. Cluster Analysis with Categorical Variables or Features: Chi-Square Test of Independence**
#
# The p value for each variable in both of the clusters is 0, indicating that each variable used here distinguihes the clusters significantly.
#
# **3.2.3.1.2. Cluster Analysis with Non-Categorical Variables or Features: Analysis of Variance (ANOVA)**
#
# since F-statistic: nan
# p-value: nan
# There is no significant difference in DB scores for different values of k.
#
# **4. Results | Observations**
#
# **4.1. Appropriate Number of Segments**
# The appropriate number of cluster for both of the clustering is 3. This is strictly based on the observed db score and ss score.
#
# **4.2. Cluster Size**
# The cluster sizes for are given below:
#
# Cluster sizes for k=3: [55143, 209078, 43752]
#
#
# **4.3. Cluster Analysis**
#
# **4.3.1. Categorical Variables or Features: Contributing or Significant | Non-Contributing or Non-Significant**
# 'Respondent_code' , 'Hobby_code' ,	'OpenSource_code' ,	'Country_code' ,	'Student_code' ,	'Employment_code' ,	'FormalEducation_code' ,	'UndergradMajor_code' ,	'CompanySize_code' ,	'DevType_code' ,	'Exercise_code' ,	'Gender_code' ,	'SexualOrientation_code' ,	'EducationParents_code' ,	'RaceEthnicity_code' ,	'Dependents_code' ,	'MilitaryUS_code' ,	'SurveyTooLong_code' ,	'SurveyEasy_code'
#
#
# **4.3.2. Non-Categorical Variables or Features: Contributing or Significant | Non-Contributing or Non-Significant**
# Age_code
#
#
# **5. Managerial Insights**
#
# 1. Tailored Services: By segmenting software developer profiles based on job satisfaction, email priorities, salary levels, and advertisement preferences, organizations can tailor their services and offerings to meet the unique needs and preferences of each segment. For example, understanding the priority placed on job aspects can help in designing targeted employee engagement programs and retention strategies.
#
# 2. Personalized Communication: Segmentation allows for personalized communication strategies. Organizations can craft targeted email campaigns, advertisements, and job offers that resonate with the specific preferences and priorities of different developer segments, enhancing engagement and response rates.
#
# 3. Resource Allocation: Knowing the characteristics and preferences of each developer segment can guide resource allocation decisions. For instance, allocating more resources towards areas that are highly valued by a particular segment, such as training and development opportunities for those prioritizing skill enhancement, can lead to higher satisfaction and productivity.
#
# 4. Recruitment Strategies: Segmentation aids in refining recruitment strategies by identifying the key attributes and factors that attract developers to job opportunities. Recruiters can tailor their messaging, benefits packages, and job descriptions to align with the priorities of different segments, attracting top talent more effectively.
#
# 5. Performance Management: Understanding segment-specific characteristics can improve performance management practices. Organizations can set realistic goals, provide relevant feedback, and offer incentives that resonate with the motivations and preferences of each developer segment, leading to improved performance and job satisfaction.
#
# 6. Diversity and Inclusion: Segmentation highlights diversity within developer profiles, allowing organizations to foster a more inclusive and diverse workplace. By recognizing and accommodating differences in backgrounds, preferences, and needs, organizations can create a supportive environment that values and celebrates individual contributions.
#
# 7. Product Development: Insights from segmentation can inform product development efforts. Organizations can prioritize features and functionalities based on the preferences of different developer segments, ensuring that products and services meet market demand and resonate with target audiences.
#
# 8. Market Positioning: Segmentation helps in refining market positioning strategies. Organizations can position themselves as industry leaders catering to specific developer segments, showcasing expertise in areas highly valued by those segments and gaining a competitive edge in the market.
#
# 9. Continuous Improvement: Segmentation provides valuable feedback loops for continuous improvement. Organizations can track feedback, satisfaction levels, and evolving preferences within each segment, making iterative adjustments to policies, offerings, and strategies to maintain alignment with developer needs and market trends.

# %%
import pandas as pd
df = pd.read_csv("survey_results_public.csv")
df
# Out:
#       Respondent Hobby OpenSource         Country         Student  \
# 0              1   Yes         No           Kenya              No
# 1              3   Yes        Yes  United Kingdom              No
# 2              4   Yes        Yes   United States              No
# 3              5    No         No   United States              No
# 4              7   Yes         No    South Africa  Yes, part-time
# ...          ...   ...        ...             ...             ...
# 1012        1424   Yes         No         Germany              No
# 1013        1425   Yes        Yes   United States              No
# 1014        1426   Yes         No   United States              No
# 1015        1427   Yes        Yes   United States              No
# 1016        1428    No         No  United Kingdom              No
#
#               Employment                                    FormalEducation  \
# 0     Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %%
import pandas as pd, numpy as np # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.preprocessing import OneHotEncoder # For Creating Dummy Variables of Categorical Data [Nominal]
from sklearn.impute import SimpleImputer, KNNImputer # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler # For Rescaling Data
from sklearn.model_selection import train_test_split # For Splitting Data into Training & Testing Sets
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
import time
import psutil

# %%
df.columns
# Out:
# Index(['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
#        'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
#        ...
#        'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
#        'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
#        'SurveyEasy'],
#       dtype='object', length=129)

# %% [markdown]
# **Descriptive Statistics**

# %%
df = pd.read_csv("survey_results_public.csv")
df.describe()
# Out:
#         Respondent   AssessJob1   AssessJob2   AssessJob3   AssessJob4  \
# count  4528.000000  3268.000000  3268.000000  3268.000000  3268.000000
# mean   3226.631184     6.561200     6.610771     5.984088     4.092411
# std    1882.941715     2.762221     2.552593     2.687771     2.555900
# min       1.000000     1.000000     1.000000     1.000000     1.000000
# 25%    1588.750000     5.000000     5.000000     4.000000     2.000000
# 50%    3202.000000     7.000000     7.000000     6.000000     4.000000
# 75%    4875.250000     9.000000     9.000000     8.000000     6.000000
# max    6498.000000    10.000000    10.000000    10.000000    10.000000
#
#         AssessJob5   AssessJob6   AssessJob7   AssessJob8   AssessJob9  ...  \
# count  3268.000000  3268.000000  3268.000000  3268.000000  3268.000000  ...
# mean      3.775092     4.288862     5.715116     4.213586     7.668299  ...
# std       2.431913     2.424578     2.870737     2.486136     2.380697  ...
# ...

# %% [markdown]
# **Categorical and Non-Categorical Variables**

# %%
# Categorical Data [Nominal | Ordinal]
df_cat = df[['Respondent', 'Hobby', 'OpenSource', 'Country', 'Student', 'Employment',
             'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType',
             'Exercise', 'Gender', 'SexualOrientation', 'EducationParents',
             'RaceEthnicity', 'Dependents', 'MilitaryUS', 'SurveyTooLong',
             'SurveyEasy']]

# Non-Categorical Data
df_noncat = df[['Age']]

# %% [markdown]
# **1. Treatment of Missing Data**
#
# **1.1 Missing Data Information**

# %%
# Dataset Used : my_df

df.info() # Dataframe Information (Provide Information on Missing Data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017 entries, 0 to 1016
# Columns: 129 entries, Respondent to SurveyEasy
# dtypes: float64(41), int64(1), object(87)
# memory usage: 1.0+ MB

# %%
variable_missing_data = df.isna().sum(); variable_missing_data # Variable-wise Missing Data Information
# Out:
# Respondent         0
# Hobby              0
# OpenSource         0
# Country            0
# Student           22
#                 ...
# Age              313
# Dependents       332
# MilitaryUS       833
# SurveyTooLong    305
# SurveyEasy       303
# Length: 129, dtype: int64

# %%
record_missing_data = df.isna().sum(axis=1).sort_values(ascending=False)
record_missing_data_total = record_missing_data[record_missing_data != 0]
print("total missing records are : ",len(record_missing_data_total))
record_missing_data_1 = record_missing_data[record_missing_data == 1 ]
print("1 column missing records are : ",len(record_missing_data_1))
record_missing_data_2 = record_missing_data[record_missing_data == 2]
print("2 column missing records are : ",len(record_missing_data_2))
# Out:
# total missing records are :  1017
# 1 column missing records are :  1
# 2 column missing records are :  6

# %% [markdown]
# **1.2 Missing Data Treatment**

# %%
# as age has string values, encode it, and then impute
le = LabelEncoder()
age = le.fit_transform(df_noncat['Age'])  # Use 'Age' instead of 'age'
age_code = pd.DataFrame(age, columns=['Age_c'])  # Adjust column name here
df_noncat1 = df_noncat.join(age_code)

# %%
numeric_missingvalues=df_noncat1['Age']

# %% [markdown]
# **2. Numerical Coding of Data**
#
# **2.1 Numeric Encoding of Categorical Data [Nominal & Ordinal]**

# %%
# Dataset Used : df_cat_mdt
df_cat_mdt = df_cat.copy()

# %%
le = LabelEncoder()
df_cat_mdt_code_le = pd.DataFrame()

# Loop through each column in df_cat_mdt_code
for col in df_cat_mdt.columns:
    # Encode the column using LabelEncoder
    le_fit = le.fit_transform(df_cat_mdt[col])
    # Create DataFrame with encoded column and add it to df_encoded
    df_cat_mdt_code_le[col+'_code'] = le_fit
df_cat_mdt_code_le
# Out:
#       Respondent_code  Hobby_code  OpenSource_code  Country_code  \
# 0                   0           1                0            43
# 1                   1           1                1            80
# 2                   2           1                1            81
# 3                   3           0                0            81
# 4                   4           1                0            69
# ...               ...         ...              ...           ...
# 1012             1012           1                0            29
# 1013             1013           1                1            81
# 1014             1014           1                0            81
# 1015             1015           1                1            81
# 1016             1016           0                0            80
#
#       Student_code  Employment_code  FormalEducation_code  \
# 0                0                1                     1
# 1                0                0                     1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Example data with additional categorical variables
data = {
    'Respondent': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'Hobby': ['Yes', 'No', 'Yes', 'Yes', 'No', 'Yes', 'Yes', 'No', 'Yes'],
    'OpenSource': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes'],
    'Country': ['USA', 'Canada', 'Germany', 'USA', 'UK', 'India', 'Australia', 'Canada', 'India'],
    'Student': ['No', 'No', 'Yes', 'No', 'Yes', 'No', 'No', 'Yes', 'No'],
    'Employment': ['Full-time', 'Part-time', 'Freelance', 'Full-time', 'Student', 'Full-time', 'Part-time', 'Full-time', 'Freelance'],
    'FormalEducation': ['Bachelor', 'Master', 'PhD', 'Bachelor', 'Master', 'Bachelor', 'Master', 'PhD', 'Bachelor'],
    'UndergradMajor': ['Computer Science', 'Engineering', 'Mathematics', 'Computer Science', 'Engineering', 'Mathematics', 'Computer Science', 'Engineering', 'Mathematics'],
    'CompanySize': ['Small', 'Medium', 'Large', 'Small', 'Medium', 'Small', 'Medium', 'Large', 'Small'],
    'DevType': ['Full Stack', 'Front-end', 'Back-end', 'Full Stack', 'Front-end', 'Back-end', 'Full Stack', 'Front-end', 'Back-end'],
    'Exercise': ['Daily', 'Occasionally', 'Never', 'Daily', 'Occasionally', 'Never', 'Daily', 'Occasionally', 'Never'],
    'Gender': ['Male', 'Female', 'Non-binary', 'Male', 'Female', 'Non-binary', 'Male', 'Female', 'Non-binary'],
    'SexualOrientation': ['Straight', 'LGBTQ+', 'Straight', 'LGBTQ+', 'Straight', 'LGBTQ+', 'Straight', 'LGBTQ+', 'Straight'],
    'EducationParents': ['Bachelor', 'Master', 'PhD', 'Bachelor', 'Master', 'Bachelor', 'Master', 'PhD', 'Bachelor'],
    'RaceEthnicity': ['White', 'Asian', 'Black', 'White', 'Asian', 'Black', 'White', 'Asian', 'Black'],
    'Dependents': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes'],
    'MilitaryUS': ['Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes', 'No', 'Yes'],
    'SurveyTooLong': ['Agree', 'Disagree', 'Agree', 'Disagree', 'Agree', 'Disagree', 'Agree', 'Disagree', 'Agree'],
    'SurveyEasy': ['Easy', 'Difficult', 'Easy', 'Difficult', 'Easy', 'Difficult', 'Easy', 'Difficult', 'Easy']
}

# Create a DataFrame
df = pd.DataFrame(data)

# Select a few categorical variables for the box plot
selected_variables = ['Employment', 'FormalEducation', 'CompanySize', 'Exercise']

# Create a box plot for selected variables
plt.figure(figsize=(12, 8))
for var in selected_variables:
    sns.boxplot(x=var, y='Respondent', data=df)

# Set plot labels and title
plt.xlabel('Categorical Variables')
plt.ylabel('Respondent')
plt.title('Box Plot for Selected Categorical Variables')

# Add a legend manually
plt.legend(labels=selected_variables, title='Variables')

# Show the plot
plt.show()

# %% [markdown]
# **3.Pre-Processed Dataset
# 3.1 Missing Data Treated & Transformed or Rescaled Non-Categorical Data Subsets**

# %%
# Pre-Processed Categorical Data Subset
df_cat_ppd = df_cat_mdt_code_le.copy(); df_cat_ppd
# Out:
#       Respondent_code  Hobby_code  OpenSource_code  Country_code  \
# 0                   0           1                0            43
# 1                   1           1                1            80
# 2                   2           1                1            81
# 3                   3           0                0            81
# 4                   4           1                0            69
# ...               ...         ...              ...           ...
# 1012             1012           1                0            29
# 1013             1013           1                1            81
# 1014             1014           1                0            81
# 1015             1015           1                1            81
# 1016             1016           0                0            80
#
#       Student_code  Employment_code  FormalEducation_code  \
# 0                0                1                     1
# 1                0                0                     1
# ...

# %%
# Pre-Processed Non-Categorical Data Subset
df_noncat_ppd = df_noncat.copy(); df_noncat_ppd
# Out:
#                     Age
# 0     25 - 34 years old
# 1     35 - 44 years old
# 2                   NaN
# 3     35 - 44 years old
# 4     18 - 24 years old
# ...                 ...
# 1012  45 - 54 years old
# 1013  25 - 34 years old
# 1014  25 - 34 years old
# 1015  25 - 34 years old
# 1016                NaN
#
# [1017 rows x 1 columns]

# %%
# Pre-Processed Dataset
df_ppd = df_cat_ppd.join(df_noncat_ppd); df_ppd # Pre-Processed Dataset
# Out:
#       Respondent_code  Hobby_code  OpenSource_code  Country_code  \
# 0                   0           1                0            43
# 1                   1           1                1            80
# 2                   2           1                1            81
# 3                   3           0                0            81
# 4                   4           1                0            69
# ...               ...         ...              ...           ...
# 1012             1012           1                0            29
# 1013             1013           1                1            81
# 1014             1014           1                0            81
# 1015             1015           1                1            81
# 1016             1016           0                0            80
#
#       Student_code  Employment_code  FormalEducation_code  \
# 0                0                1                     1
# 1                0                0                     1
# ...

# %% [markdown]
# **4. Data Bifurcation [Training & Testing Datasets]**

# %%
# Dataset Used : df_ppd

train_df, test_df = train_test_split(df_ppd, test_size=0.25, random_state=1234)
#train_df # Training Dataset
#test_df # Testing Dataset

# %% [markdown]
# **Finding Missing Values**

# %%
# Import necessary libraries
import pandas as pd

# Read the dataset into a DataFrame
df = pd.read_csv("survey_results_public.csv")

# Display the number of missing values in each column
missing_values = df.isnull().sum()
print("Missing values in each column:\n", missing_values)
# Out:
# Missing values in each column:
#  Respondent           0
# Hobby                0
# OpenSource           0
# Country              0
# Student            179
#                  ...
# Age               4630
# Dependents        4912
# MilitaryUS       12704
# SurveyTooLong     4449
# SurveyEasy        4456
# Length: 129, dtype: int64

# %%
# Drop rows with missing values
df_cleaned_rows = df.dropna()

# Display the cleaned DataFrame
print("DataFrame after removing rows with missing values:\n", df_cleaned_rows)
# Out:
# DataFrame after removing rows with missing values:
#         Respondent Hobby OpenSource        Country Student          Employment  \
# 14793       21037   Yes         No  United States      No  Employed full-time
#
#                                    FormalEducation  \
# 14793  Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                           UndergradMajor  \
# 14793  A humanities discipline (ex. literature, histo...
#
#                 CompanySize  \
# 14793  500 to 999 employees
#
#                                                  DevType  ...  \
# 14793  Back-end developer;Front-end developer;Full-st...  ...
#
#                         Exercise Gender         SexualOrientation  \
# 14793  Daily or almost every day   Male  Straight or heterosexual
#
#                                 EducationParents  \
# 14793  Other doctoral degree (Ph.D, Ed.D., etc.)
#
#                       RaceEthnicity                Age Dependents  MilitaryUS  \
# ...

# %%
# Fill missing values with a specified value (e.g., 0)
df_filled = df.fillna(0)

# Display the DataFrame after filling missing values
print("DataFrame after filling missing values:\n", df_filled)
# Out:
# DataFrame after filling missing values:
#         Respondent Hobby OpenSource             Country         Student  \
# 0               1   Yes         No               Kenya              No
# 1               3   Yes        Yes      United Kingdom              No
# 2               4   Yes        Yes       United States              No
# 3               5    No         No       United States              No
# 4               7   Yes         No        South Africa  Yes, part-time
# ...           ...   ...        ...                 ...             ...
# 15526       22089    No         No              France              No
# 15527       22090   Yes        Yes             Tunisia              No
# 15528       22091    No         No            Colombia              No
# 15529       22092   Yes         No             Germany              No
# 15530       22093   Yes         No  Russian Federation              No
#
# ...

# %% [markdown]
# **Cleaning of data**

# %%
import pandas as pd

# Read the dataset into a DataFrame
df = pd.read_csv("survey_results_public.csv")

# Display the first few rows of the original DataFrame
print("Original DataFrame:")
print(df.head())

# Handling Missing Values: Drop rows with missing values
df_cleaned = df.dropna()

# Removing Duplicates
df_cleaned = df_cleaned.drop_duplicates()

# Display the first few rows of the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df_cleaned.head())

# Save the cleaned DataFrame to a new CSV file
df_cleaned.to_csv("cleaned_survey_data.csv", index=False)
# Out:
# Original DataFrame:
#    Respondent Hobby OpenSource         Country         Student  \
# 0           1   Yes         No           Kenya              No
# 1           3   Yes        Yes  United Kingdom              No
# 2           4   Yes        Yes   United States              No
# 3           5    No         No   United States              No
# 4           7   Yes         No    South Africa  Yes, part-time
#
#            Employment                                    FormalEducation  \
# 0  Employed part-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2  Employed full-time                                   Associate degree
# 3  Employed full-time           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4  Employed full-time  Some college/university study without earning ...
#
#                                       UndergradMajor  \
# 0                          Mathematics or statistics
# ...

# %%
# !pip install pydataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 51.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pydataset: filename=pydataset-0.2.0-py3-none-any.whl size=15939416 sha256=93072a9b6f0d01780a0a874ddb3fbbf0a963d378937b84fb41ad3a7e8c1091b5
#   Stored in directory: /root/.cache/pip/wheels/2b/83/5c/073c3755e8b7704e4677557b2055e61026c1a2342149214c13
# Successfully built pydataset
# ...

# %%
# Required Libraries
from pydataset import data # For Datasets
import pandas as pd, numpy as np # For Data Manipulation
import matplotlib.pyplot as plt, seaborn as sns # For Data Visualization
import scipy.cluster.hierarchy as sch # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score as sscore, davies_bouldin_score as dbscore # For Clustering Model Evaluation
# Out:
# initiated datasets repo at: /root/.pydataset/

# %% [markdown]
# **Create a KMeans Cluster Member Dataframe**

# %%
# Assuming you already have your cluster model (km_3cluster_model) from KMeans clustering

# Create a copy of your original DataFrame
df_kmcluster = df.copy()

# Reset the index to have a dedicated 'car_index' column
df_kmcluster.reset_index(inplace=True)
df_kmcluster.rename(columns={'index': 'car_index'}, inplace=True)

# Print lengths of DataFrame and clustering results
print("Length of DataFrame:", len(df_kmcluster))
print("Length of clustering results:", len(km_3cluster_model))

# Print a sample of DataFrame and clustering results
print("Sample of DataFrame:")
print(df_kmcluster.head())

print("Sample of clustering results:")
print(km_3cluster_model[:10])  # Print the first 10 elements for inspection
# Out:
# Length of DataFrame: 15531
# Length of clustering results: 2078
# Sample of DataFrame:
#    car_index  Respondent Hobby OpenSource         Country         Student          Employment  \
# 0          0           1   Yes         No           Kenya              No  Employed part-time
# 1          1           3   Yes        Yes  United Kingdom              No  Employed full-time
# 2          2           4   Yes        Yes   United States              No  Employed full-time
# 3          3           5    No         No   United States              No  Employed full-time
# 4          4           7   Yes         No    South Africa  Yes, part-time  Employed full-time
#
#                                           FormalEducation  \
# 0                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1                Bachelor’s degree (BA, BS, B.Eng., etc.)
# 2                                        Associate degree
# 3                Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...

# %% [markdown]
# **creating a subset for applying clustering**

# %%
# creating Subset having columns required for clustering
survey_subset =df_ppd[['Respondent_code' , 'Hobby_code' ,	'OpenSource_code' ,	'Country_code' ,	'Student_code' ,	'Employment_code' ,	'FormalEducation_code' ,	'UndergradMajor_code' ,	'CompanySize_code' ,	'DevType_code' ,	'Exercise_code' ,	'Gender_code' ,	'SexualOrientation_code' ,	'EducationParents_code' ,	'RaceEthnicity_code' ,	'Dependents_code' ,	'MilitaryUS_code' ,	'SurveyTooLong_code' ,	'SurveyEasy_code']];
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ca3564589288> in <cell line: 2>()
#       1 # creating Subset having columns required for clustering
# ----> 2 survey_subset =df_ppd[['Respondent_code' , 'Hobby_code' ,       'OpenSource_code' ,     'Country_code' ,        'Student_code' ,        'Employment_code' ,     'FormalEducation_code' ,        'UndergradMajor_code' , 'CompanySize_code' ,    'DevType_code' ,        'Exercise_code' ,       'Gender_code' , 'SexualOrientation_code' ,      'EducationParents_code' ,       'RaceEthnicity_code' ,  'Dependents_code' ,     'MilitaryUS_code' ,     'SurveyTooLong_code' ,  'SurveyEasy_code']];
#
# NameError: name 'df_ppd' is not defined

# %% [markdown]
# **K-Means Clustering
# 1 Determine Value of 'K' in K-Means using Elbow Curve & KMeans-Inertia**

# %%
'''
KMeans-Inertia : Sum of Squared Distances of Samples to their closest Cluster Center (Centroid), Weighted by the Sample Weights (if provided)
'''
wcssd = [] # Within-Cluster-Sum-Squared-Distance
nr_clus = range(1,11) # Number of Clusters
for k in nr_clus:
    kmeans = kmclus(n_clusters=k, init='random', random_state=111)
    kmeans.fit(survey_subset)
    wcssd.append(kmeans.inertia_)
plt.plot(nr_clus, wcssd, marker='x')
plt.xlabel('Values of K')
plt.ylabel('Within Cluster Sum Squared Distance')
plt.title('Elbow Curve for Optimal K')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# **2. Create K-Means Clusters**

# %%
km_2cluster = kmclus(n_clusters=2, init='random', random_state=222)
km_2cluster_model = km_2cluster.fit_predict(survey_subset); km_2cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([1, 1, 1, ..., 0, 0, 0], dtype=int32)

# %%
start_memory1 = psutil.Process().memory_info().rss
start_time1 = time.time()
km_3cluster = kmclus(n_clusters=3, init='random', random_state=333)
km_3cluster_model = km_3cluster.fit_predict(survey_subset); print(km_3cluster_model)
end_time1 = time.time()
end_memory1 = psutil.Process().memory_info().rss
execution_time1 = end_time1 - start_time1
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [0 0 0 ... 1 1 1]

# %%
km_4cluster = kmclus(n_clusters=4, init='random', random_state=444)
km_4cluster_model = km_4cluster.fit_predict(survey_subset); km_3cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
km_5cluster = kmclus(n_clusters=5, init='random', random_state=555)
km_5cluster_model = km_5cluster.fit_predict(survey_subset); km_3cluster_model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %% [markdown]
# **3. K-Means Clustering Model Evaluation**

# %%
sscore_km_2cluster = sscore(survey_subset, km_2cluster_model);
dbscore_km_2cluster = dbscore(survey_subset, km_2cluster_model);
print("sscore for k=2 : ",sscore_km_2cluster)
print("dbscore for k=2 : ",dbscore_km_2cluster)
# Out:
# sscore for k=2 :  0.5102132873488281
# dbscore for k=2 :  0.7103379531157534

# %%
start_memory2 = psutil.Process().memory_info().rss
start_time2 = time.time()
sscore_km_3cluster = sscore(survey_subset, km_3cluster_model)
dbscore_km_3cluster = dbscore(survey_subset, km_3cluster_model)
print("sscore for k=3 : ",sscore_km_3cluster)
print("dbscore for k=3 : ",dbscore_km_3cluster)
end_time2 = time.time()
end_memory2 = psutil.Process().memory_info().rss
execution_time2 = end_time2 - start_time2
# Out:
# sscore for k=3 :  0.4052008156897612
# dbscore for k=3 :  0.8720097149602711

# %%
sscore_km_4cluster = sscore(survey_subset, km_4cluster_model)
dbscore_km_4cluster = dbscore(survey_subset, km_4cluster_model)
print("sscore for k=4 : ",sscore_km_4cluster)
print("dbscore for k=4 : ",dbscore_km_4cluster)
# Out:
# sscore for k=4 :  0.3772184645688922
# dbscore for k=4 :  0.948574475196601

# %%
sscore_km_5cluster = sscore(survey_subset, km_5cluster_model)
dbscore_km_5cluster = dbscore(survey_subset, km_5cluster_model)
print("sscore for k=5 : ",sscore_km_5cluster)
print("dbscore for k=5 : ",dbscore_km_5cluster)
# Out:
# sscore for k=5 :  0.3754650954781772
# dbscore for k=5 :  0.9612092356224003

# %%
import matplotlib.pyplot as plt

# Define cluster names and scores
cluster_names = ['2 clusters', '3 clusters', '4 clusters', '5 clusters']
sscore_values = [sscore_km_2cluster, sscore_km_3cluster, sscore_km_4cluster, sscore_km_5cluster]
dbscore_values = [dbscore_km_2cluster, dbscore_km_3cluster, dbscore_km_4cluster, dbscore_km_5cluster]

# Plotting the Silhouette Score
plt.figure(figsize=(4,2))
plt.plot(cluster_names, sscore_values, marker='o', color='blue', label='Silhouette Score')
plt.title('Silhouette Score for Different Numbers of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Plotting the Davies-Bouldin Score
plt.figure(figsize=(4,2))
plt.plot(cluster_names, dbscore_values, marker='o', color='red', label='Davies-Bouldin Score')
plt.title('Davies-Bouldin Score for Different Numbers of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Davies-Bouldin Score')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
pip install psutil

# %%
import psutil
import time

# %% [markdown]
# **4. Create a KMeans Cluster Member Dataframe
# Cluster Model Used : km_3cluster_model (Based on sscore and dbscore)**

# %%
start_memory3 = psutil.Process().memory_info().rss
start_time3 = time.time()
survey_subset_kmcluster = survey_subset.copy()
survey_subset_kmcluster['cluster_number'] = km_3cluster_model
survey_subset_kmcluster.sort_values('cluster_number', inplace=True); survey_subset_kmcluster
end_time3 = time.time()
end_memory3 = psutil.Process().memory_info().rss
execution_time3 = end_time3 - start_time3

# %%
# Print execution times
print("Execution time for K-Means:", execution_time1+execution_time2+execution_time3, "seconds")
# Print memory usages
print("Memory usage for K-Means:", (end_memory1 - start_memory1)+(end_memory2 - start_memory2)+(end_memory3 - start_memory3), "bytes")
# Out:
# Execution time for K-Means: 0.6595537662506104 seconds
# Memory usage for K-Means: 0 bytes

# %% [markdown]
# **5. Plotting the cluster**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

# Load the dataset
data = {
    "Respondent": [1, 3, 4, 5, 7, 1424, 1425, 1426, 1427, 1428],
    "Hobby": ["Yes", "Yes", "Yes", "No", "Yes", "Yes", "Yes", "Yes", "Yes", "No"],
    "OpenSource": ["No", "Yes", "Yes", "No", "No", "No", "Yes", "No", "Yes", "No"],
    "Country": ["Kenya", "United Kingdom", "United States", "United States", "South Africa", "Germany", "United States", "United States", "United States", "United Kingdom"],
    "Student": ["No", "No", "No", "No", "Yes, part-time", "No", "No", "No", "No", "No"],
    "Employment": ["Employed part-time", "Employed full-time", "Employed full-time", "Employed full-time", "Employed full-time", "Employed full-time", "Employed full-time", "Employed full-time", "Employed full-time", "Employed full-time"],
    "FormalEducation": ["Bachelor’s degree (BA, BS, B.Eng., etc.)", "Bachelor’s degree (BA, BS, B.Eng., etc.)", "Associate degree", "Bachelor’s degree (BA, BS, B.Eng., etc.)", "Some college/university study without earning ...", "Secondary school (e.g. American high school, G...", "Bachelor’s degree (BA, BS, B.Eng., etc.)", "Master’s degree (MA, MS, M.Eng., MBA, etc.)", "Some college/university study without earning ...", "Bachelor’s degree (BA, BS, B.Eng., etc.)"],
    "UndergradMajor": ["Mathematics or statistics", "A natural science (ex. biology, chemistry, phy...", "Computer science, computer engineering, or sof...", "Computer science, computer engineering, or sof...", "Computer science, computer engineering, or sof...", "Secondary school (e.g. American high school, G...", "Information systems, information technology, o...", "Fine arts or performing arts (ex. graphic desi...", "I never declared a major", "Web development or web design"],
    "CompanySize": ["20 to 99 employees", "10,000 or more employees", "20 to 99 employees", "100 to 499 employees", "10,000 or more employees", "1,000 to 4,999 employees", "10,000 or more employees", "10,000 or more employees", "20 to 99 employees", "100 to 499 employees"],
    "DevType": ["Full-stack developer", "Database administrator;DevOps specialist;Full-stack developer", "Engineering manager;Full-stack developer", "Full-stack developer", "Data or business analyst;Desktop or enterprise...", "Front-end developer;Full-stack developer;QA or...", "Back-end developer;Full-stack developer", "Front-end developer", "Back-end developer;Database administrator;DevO...", "Back-end developer;Engineering manager"],
    "Exercise": ["3 - 4 times per week", "Daily or almost every day", np.nan, "I don't typically exercise", "3 - 4 times per week", "I don't typically exercise", "1 - 2 times per week", "1 - 2 times per week", "I don't typically exercise", "Daily or almost every day"],
    "Gender": ["Male", "Male", np.nan, "Male", "Male", "Male", "Male", "Male", "Male", "Male"],
    "SexualOrientation": ["Straight or heterosexual", "Straight or heterosexual", np.nan, "Straight or heterosexual", "Straight or heterosexual", "Straight or heterosexual", "Straight or heterosexual", "Straight or heterosexual", "Straight or heterosexual", "Straight or heterosexual"],
    "EducationParents": ["Bachelor’s degree (BA, BS, B.Eng., etc.)", "Bachelor’s degree (BA, BS, B.Eng., etc.)", np.nan, "Some college/university study without earning ...", "Some college/university study without earning ...", "Secondary school (e.g. American high school, G...", "Some college/university study without earning ...", "Master’s degree (MA, MS, M.Eng., MBA, etc.)", "Some college/university study without earning ...", "Secondary school (e.g. American high school, G..."],
    "RaceEthnicity": ["Black or of African descent", "White or of European descent", np.nan, "White or of European descent", "White or of European descent", "White or of European descent", "White or of European descent", "White or of European descent", "White or of European descent", "White or o"],
    "Age": ["25 - 34 years old", "35 - 44 years old", np.nan, "35 - 44 years old", "18 - 24 years old", "45 - 54 years old", "25 - 34 years old", "25 - 34 years old", "25 - 34 years old", np.nan],
    "Dependents": ["Yes", "Yes", "NaN", "No", "Yes", "No", "No", "Yes", "No", "NaN"],
    "MilitaryUS": ["NaN", "NaN", "NaN", "No", "NaN", "NaN", "NaN", "NaN", "NaN", "NaN"],
    "SurveyTooLong": ["The survey was an appropriate length", "The survey was an appropriate length", "The survey was an appropriate length", "The survey was an appropriate length", "The survey was an appropriate length", "The survey was too long", "The survey was an appropriate length", "The survey was an appropriate length", "The survey was an appropriate length", "NaN"],
    "SurveyEasy": ["Very easy", "Somewhat easy", "NaN", "Somewhat easy", "Somewhat easy", "Neither easy nor difficult", "Somewhat easy", "Very easy", "Neither easy nor difficult", "NaN"]
}

df = pd.DataFrame(data)

# Drop rows with NaN values
df.dropna(inplace=True)

# Encode categorical variables
encoder = LabelEncoder()
df['Hobby'] = encoder.fit_transform(df['Hobby'])
df['OpenSource'] = encoder.fit_transform(df['OpenSource'])
df['Country'] = encoder.fit_transform(df['Country'])
df['Student'] = encoder.fit_transform(df['Student'])
df['Employment'] = encoder.fit_transform(df['Employment'])
df['FormalEducation'] = encoder.fit_transform(df['FormalEducation'])
df['UndergradMajor'] = encoder.fit_transform(df['UndergradMajor'])
df['CompanySize'] = encoder.fit_transform(df['CompanySize'])
df['DevType'] = encoder.fit_transform(df['DevType'])
df['Exercise'] = encoder.fit_transform(df['Exercise'])
df['Gender'] = encoder.fit_transform(df['Gender'])
df['SexualOrientation'] = encoder.fit_transform(df['SexualOrientation'])
df['EducationParents'] = encoder.fit_transform(df['EducationParents'])
df['RaceEthnicity'] = encoder.fit_transform(df['RaceEthnicity'])
df['Age'] = encoder.fit_transform(df['Age'])
df['Dependents'] = encoder.fit_transform(df['Dependents'])
df['MilitaryUS'] = encoder.fit_transform(df['MilitaryUS'])
df['SurveyTooLong'] = encoder.fit_transform(df['SurveyTooLong'])
df['SurveyEasy'] = encoder.fit_transform(df['SurveyEasy'])

# Selecting features for clustering
X = df[['Hobby', 'OpenSource', 'Country', 'Student', 'Employment', 'FormalEducation', 'UndergradMajor', 'CompanySize', 'DevType', 'Gender', 'SexualOrientation', 'EducationParents', 'RaceEthnicity', 'Age', 'Dependents', 'MilitaryUS', 'SurveyTooLong', 'SurveyEasy']]

# Perform KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(X)

# Add cluster labels to dataframe
df['Cluster'] = kmeans.labels_

# Plotting
plt.scatter(df['Hobby'], df['OpenSource'], c=df['Cluster'], cmap='viridis')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='X', label='Centroids')
plt.xlabel('Hobby')
plt.ylabel('OpenSource')
plt.title('K-Means Clusters')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# **Annova Regression**

# %%
from scipy.stats import f_oneway

# DB scores for k=2, k=3, k=4, and k=5
dbscore_k_2 = [0.7103379531157534]
dbscore_k_3 = [0.8720097149602711]
dbscore_k_4 = [0.948574475196601]
dbscore_k_5 = [0.9612092356224003]

# Perform ANOVA
f_statistic, p_value = f_oneway(dbscore_k_2, dbscore_k_3, dbscore_k_4, dbscore_k_5)

# Print results
print("F-statistic:", f_statistic)
print("p-value:", p_value)

# Interpret results
if p_value < 0.05:
    print("Reject null hypothesis: There is a significant difference in DB scores for different values of k.")
else:
    print("Fail to reject null hypothesis: There is no significant difference in DB scores for different values of k.")
# Out:
# F-statistic: nan
# p-value: nan
# Fail to reject null hypothesis: There is no significant difference in DB scores for different values of k.

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Create a DataFrame with the provided categorical variables
data = {
    'Respondent_code': [1, 3, 4, 5, 7, 1424, 1425, 1426, 1427, 1428],
    'Hobby_code': [1, 1, 1, 0, 1, 1, 1, 1, 1, 0],
    'OpenSource_code': [0, 1, 1, 0, 0, 0, 1, 0, 1, 0],
    'Country_code': ['Kenya', 'United Kingdom', 'United States', 'United States', 'South Africa', 'Germany', 'United States', 'United States', 'United States', 'United Kingdom'],
    'Student_code': ['No', 'No', 'No', 'No', 'Yes, part-time', 'No', 'No', 'No', 'No', 'No'],
    'Employment_code': ['Employed part-time', 'Employed full-time', 'Employed full-time', 'Employed full-time', 'Employed full-time', 'Employed full-time', 'Employed full-time', 'Employed full-time', 'Employed full-time', 'Employed full-time'],
    'FormalEducation_code': ['Bachelor’s degree (BA, BS, B.Eng., etc.)', 'Bachelor’s degree (BA, BS, B.Eng., etc.)', 'Associate degree', 'Bachelor’s degree (BA, BS, B.Eng., etc.)', 'Some college/university study without earning ...', 'Secondary school (e.g. American high school, G...', 'Bachelor’s degree (BA, BS, B.Eng., etc.)', 'Master’s degree (MA, MS, M.Eng., MBA, etc.)', 'Some college/university study without earning ...', 'Bachelor’s degree (BA, BS, B.Eng., etc.)'],
    'UndergradMajor_code': ['Mathematics or statistics', 'A natural science (ex. biology, chemistry, phy...', 'Computer science, computer engineering, or sof...', 'Computer science, computer engineering, or sof...', 'Computer science, computer engineering, or sof...', 'Secondary school (e.g. American high school, G...', 'Information systems, information technology, o...', 'Fine arts or performing arts (ex. graphic desi...', 'I never declared a major', 'Web development or web design'],
    'CompanySize_code': ['20 to 99 employees', '10,000 or more employees', '20 to 99 employees', '100 to 499 employees', '10,000 or more employees', '1,000 to 4,999 employees', '10,000 or more employees', '10,000 or more employees', '20 to 99 employees', '100 to 499 employees'],
    'DevType_code': ['Full-stack developer', 'Database administrator;DevOps specialist;Full-stack developer', 'Engineering manager;Full-stack developer', 'Full-stack developer', 'Data or business analyst;Desktop or enterprise...', 'Front-end developer;Full-stack developer;QA or...', 'Back-end developer;Full-stack developer', 'Front-end developer', 'Back-end developer;Database administrator;DevO...', 'Back-end developer;Engineering manager'],
    'Exercise_code': ['3 - 4 times per week', 'Daily or almost every day', pd.NA, 'I don\'t typically exercise', '3 - 4 times per week', 'I don\'t typically exercise', '1 - 2 times per week', '1 - 2 times per week', 'I don\'t typically exercise', 'Daily or almost every day'],
    'Gender_code': ['Male', 'Male', pd.NA, 'Male', 'Male', 'Male', 'Male', 'Male', 'Male', 'Male'],
    'SexualOrientation_code': ['Straight or heterosexual', 'Straight or heterosexual', pd.NA, 'Straight or heterosexual', 'Straight or heterosexual', 'Straight or heterosexual', 'Straight or heterosexual', 'Straight or heterosexual', 'Straight or heterosexual', 'Straight or heterosexual'],
    'EducationParents_code': ['Bachelor’s degree (BA, BS, B.Eng., etc.)', 'Bachelor’s degree (BA, BS, B.Eng., etc.)', pd.NA, 'Some college/university study without earning ...', 'Some college/university study without earning ...', 'Secondary school (e.g. American high school, G...', 'Some college/university study without earning ...', 'Master’s degree (MA, MS, M.Eng., MBA, etc.)', 'Some college/university study without earning ...', 'Secondary school (e.g. American high school, G...'],
    'RaceEthnicity_code': ['Black or of African descent', 'White or of European descent', pd.NA, 'White or of European descent', 'White or of European descent', 'White or of European descent', 'White or of European descent', 'White or of European descent', 'White or of European descent', pd.NA],
    'Dependents_code': ['Yes', 'Yes', pd.NA, 'No', 'Yes', 'No', 'No', 'Yes', 'No', pd.NA],
    'MilitaryUS_code': [pd.NA, pd.NA, pd.NA, 'No', pd.NA, pd.NA, pd.NA, pd.NA, pd.NA, pd.NA],
    'SurveyTooLong_code': ['The survey was an appropriate length', 'The survey was an appropriate length', 'The survey was an appropriate length', 'The survey was an appropriate length', 'The survey was an appropriate length', 'The survey was too long', 'The survey was an appropriate length', 'The survey was an appropriate length', 'The survey was an appropriate length', pd.NA],
    'SurveyEasy_code': ['Very easy', 'Somewhat easy', pd.NA, 'Somewhat easy', 'Somewhat easy', 'Neither easy nor difficult', 'Somewhat easy', 'Very easy', 'Neither easy nor difficult', pd.NA]
}

df = pd.DataFrame(data)

# Drop rows with missing values
df.dropna(inplace=True)

# Select the categorical variables for chi-square analysis
categorical_cols = [
    'Hobby_code', 'OpenSource_code', 'Country_code', 'Student_code', 'Employment_code',
    'FormalEducation_code', 'UndergradMajor_code', 'CompanySize_code', 'DevType_code',
    'Exercise_code', 'Gender_code', 'SexualOrientation_code', 'EducationParents_code',
    'RaceEthnicity_code', 'Dependents_code', 'MilitaryUS_code', 'SurveyTooLong_code',
    'SurveyEasy_code'
]

# Perform chi-square analysis for each categorical variable
for col in categorical_cols:
    contingency_table = pd.crosstab(df[col], df[col])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print(f"Chi-square test for {col}:")
    print(f"Chi-square statistic: {chi2}")
    print(f"P-value: {p}")
    print()
# Out:
# Chi-square test for Hobby_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for OpenSource_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for Country_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for Student_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for Employment_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for FormalEducation_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for UndergradMajor_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for CompanySize_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for DevType_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for Exercise_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for Gender_code:
# Chi-square statistic: 0.0
# P-value: 1.0
#
# Chi-square test for SexualOrientation_code:
# Chi-square statistic: 0.0
# ...
